# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | two rivers
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | constitucion
# Processing Record 4 of Set 1 | meulaboh
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | pingliang
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | sao geraldo do araguaia
# Processing Record 14 of Set 1 | kalemie
# Processing Record 15 of Set 1 | umm lajj
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | avera
# Processing Record 22 of Set 1 | ambilobe
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | kimbe
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | dong hoi
# Processing Record 32 of Set 1 | paamiut
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | port hedland
# Processing Record 35 of Set 1 | isangel
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | vallenar
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | fort nelson
# Processing Record 42 of Set 1 | maceio
# Processing Record 43 of Set 1 | codrington
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | kamennomostskoye
# Processing Record 47 of Set 1 | mehamn
# Processing Record 48 of Set 1 | santa rosa
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | kaliua
# Processing Record 1 of Set 2 | usogorsk
# Processing Record 2 of Set 2 | westport
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | powell
# Processing Record 5 of Set 2 | lagunas
# Processing Record 6 of Set 2 | soe
# Processing Record 7 of Set 2 | sibu
# Processing Record 8 of Set 2 | almaznyy
# Processing Record 9 of Set 2 | talnakh
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | ingham
# Processing Record 12 of Set 2 | trincomalee
# Processing Record 13 of Set 2 | javanrud
# Processing Record 14 of Set 2 | shkotovo-26
# City not found. Skipping...
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | jasper
# Processing Record 17 of Set 2 | airai
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | luau
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | ulaangom
# Processing Record 25 of Set 2 | okhotsk
# Processing Record 26 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | kantang
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | hirara
# Processing Record 32 of Set 2 | skibbereen
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | inta
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | sann
# Processing Record 37 of Set 2 | sabha
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | te anau
# Processing Record 40 of Set 2 | kyren
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | grahamstown
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | baruun-urt
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | adiake
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | keuruu
# Processing Record 2 of Set 3 | worthington
# Processing Record 3 of Set 3 | liyang
# Processing Record 4 of Set 3 | puerto rico
# Processing Record 5 of Set 3 | adwa
# Processing Record 6 of Set 3 | gornopravdinsk
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 3 | tual
# Processing Record 10 of Set 3 | palu
# Processing Record 11 of Set 3 | cockburn town
# Processing Record 12 of Set 3 | siniscola
# Processing Record 13 of Set 3 | riyadh
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | tahara
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | bajna
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | naze
# Processing Record 22 of Set 3 | makakilo city
# Processing Record 23 of Set 3 | mao
# Processing Record 24 of Set 3 | cairns
# Processing Record 25 of Set 3 | fort saint james
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | valparaiso
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | iskateley
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | kathmandu
# Processing Record 33 of Set 3 | srivardhan
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 3 | daxian
# City not found. Skipping...
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | goure
# Processing Record 39 of Set 3 | tautira
# Processing Record 40 of Set 3 | borba
# Processing Record 41 of Set 3 | vanimo
# Processing Record 42 of Set 3 | sinop
# Processing Record 43 of Set 3 | prescott
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | los llanos de aridane
# Processing Record 46 of Set 3 | geraldton
# Processing Record 47 of Set 3 | imbituba
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | puerto leguizamo
# Processing Record 1 of Set 4 | peniche
# Processing Record 2 of Set 4 | bonavista
# Processing Record 3 of Set 4 | itarema
# Processing Record 4 of Set 4 | quatre cocos
# Processing Record 5 of Set 4 | tutoia
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | lorengau
# Processing Record 8 of Set 4 | killybegs
# Processing Record 9 of Set 4 | fort morgan
# Processing Record 10 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 4 | katsina
# Processing Record 12 of Set 4 | puerto colombia
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | bastrop
# Processing Record 15 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 4 | ust-nera
# Processing Record 17 of Set 4 | pelym
# Processing Record 18 of Set 4 | pamekasan
# Processing Record 19 of Set 4 | berbera
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | henties bay
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | bongor
# Processing Record 24 of Set 4 | jieshi
# Processing Record 25 of Set 4 | ostrovnoy
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | payakumbuh
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | caravelas
# Processing Record 31 of Set 4 | raudeberg
# Processing Record 32 of Set 4 | barcelona
# Processing Record 33 of Set 4 | lanxi
# Processing Record 34 of Set 4 | ambon
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | trelew
# Processing Record 37 of Set 4 | petoa
# Processing Record 38 of Set 4 | ponta do sol
# Processing Record 39 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 4 | ekhabi
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | nurota
# Processing Record 43 of Set 4 | union
# Processing Record 44 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 45 of Set 4 | pakxan
# Processing Record 46 of Set 4 | nikolskoye
# Processing Record 47 of Set 4 | mandalay
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | coolum beach
# Processing Record 50 of Set 4 | olga
# Processing Record 1 of Set 5 | faanui
# Processing Record 2 of Set 5 | povoa de varzim
# Processing Record 3 of Set 5 | hilo
# Processing Record 4 of Set 5 | jalu
# Processing Record 5 of Set 5 | tukrah
# Processing Record 6 of Set 5 | belaya gora
# Processing Record 7 of Set 5 | falaleu
# City not found. Skipping...
# Processing Record 8 of Set 5 | gewane
# Processing Record 9 of Set 5 | tateyama
# Processing Record 10 of Set 5 | yar-sale
# Processing Record 11 of Set 5 | mayor pablo lagerenza
# Processing Record 12 of Set 5 | sosnovo-ozerskoye
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | miri
# Processing Record 15 of Set 5 | vysokogornyy
# Processing Record 16 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | yulara
# Processing Record 19 of Set 5 | ios
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 5 | koplik
# Processing Record 23 of Set 5 | junction city
# Processing Record 24 of Set 5 | sumenep
# Processing Record 25 of Set 5 | utmanzai
# Processing Record 26 of Set 5 | olafsvik
# Processing Record 27 of Set 5 | luderitz
# Processing Record 28 of Set 5 | marrakesh
# Processing Record 29 of Set 5 | dickinson
# Processing Record 30 of Set 5 | minbu
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | merauke
# Processing Record 33 of Set 5 | pirai do sul
# Processing Record 34 of Set 5 | darhan
# Processing Record 35 of Set 5 | icod de los vinos
# Processing Record 36 of Set 5 | ilulissat
# Processing Record 37 of Set 5 | longyearbyen
# Processing Record 38 of Set 5 | salo
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | marsh harbour
# Processing Record 41 of Set 5 | coquimbo
# Processing Record 42 of Set 5 | tongren
# Processing Record 43 of Set 5 | celestun
# Processing Record 44 of Set 5 | wattegama
# Processing Record 45 of Set 5 | osoyoos
# Processing Record 46 of Set 5 | houma
# Processing Record 47 of Set 5 | haapiti
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | ust-ishim
# Processing Record 50 of Set 5 | mount isa
# Processing Record 1 of Set 6 | mithimna
# City not found. Skipping...
# Processing Record 2 of Set 6 | muros
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | barabai
# Processing Record 6 of Set 6 | ixtapa
# Processing Record 7 of Set 6 | tromso
# Processing Record 8 of Set 6 | santa maria
# Processing Record 9 of Set 6 | port alfred
# Processing Record 10 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 6 | bolshevik
# Processing Record 12 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | atherton
# Processing Record 15 of Set 6 | jaca
# Processing Record 16 of Set 6 | teya
# Processing Record 17 of Set 6 | maicao
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | cortland
# Processing Record 21 of Set 6 | poptun
# Processing Record 22 of Set 6 | karachi
# Processing Record 23 of Set 6 | grand-santi
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | xuddur
# Processing Record 26 of Set 6 | yate
# Processing Record 27 of Set 6 | bereda
# Processing Record 28 of Set 6 | smidovich
# Processing Record 29 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 6 | logan
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | grindavik
# Processing Record 33 of Set 6 | surab
# Processing Record 34 of Set 6 | synya
# Processing Record 35 of Set 6 | chilca
# Processing Record 36 of Set 6 | sao felix do xingu
# Processing Record 37 of Set 6 | saint-augustin
# Processing Record 38 of Set 6 | kumbo
# Processing Record 39 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 6 | pundaguitan
# Processing Record 41 of Set 6 | batagay-alyta
# Processing Record 42 of Set 6 | sao joao da barra
# Processing Record 43 of Set 6 | kananga
# Processing Record 44 of Set 6 | cap malheureux
# Processing Record 45 of Set 6 | benguela
# Processing Record 46 of Set 6 | kaihua
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | nelson bay
# Processing Record 49 of Set 6 | dahra
# Processing Record 50 of Set 6 | lagoa
# Processing Record 1 of Set 7 | mbandaka
# Processing Record 2 of Set 7 | koslan
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | poum
# Processing Record 6 of Set 7 | mocuba
# Processing Record 7 of Set 7 | atbasar
# Processing Record 8 of Set 7 | kisangani
# Processing Record 9 of Set 7 | simbahan
# Processing Record 10 of Set 7 | touros
# Processing Record 11 of Set 7 | espanola
# Processing Record 12 of Set 7 | belsand
# Processing Record 13 of Set 7 | torbay
# Processing Record 14 of Set 7 | ishigaki
# Processing Record 15 of Set 7 | bandarbeyla
# Processing Record 16 of Set 7 | harper
# Processing Record 17 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 7 | nizwa
# Processing Record 20 of Set 7 | mayna
# Processing Record 21 of Set 7 | omboue
# Processing Record 22 of Set 7 | omsukchan
# Processing Record 23 of Set 7 | porto santo
# Processing Record 24 of Set 7 | saint-junien
# Processing Record 25 of Set 7 | kuusamo
# Processing Record 26 of Set 7 | kaeo
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 7 | carmen
# Processing Record 30 of Set 7 | san andres
# Processing Record 31 of Set 7 | hithadhoo
# Processing Record 32 of Set 7 | kaspiyskiy
# Processing Record 33 of Set 7 | taywarah
# Processing Record 34 of Set 7 | mahajanga
# Processing Record 35 of Set 7 | sainte-suzanne
# Processing Record 36 of Set 7 | kefamenanu
# Processing Record 37 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 7 | suntar
# Processing Record 39 of Set 7 | dunedin
# Processing Record 40 of Set 7 | ahuimanu
# Processing Record 41 of Set 7 | adrar
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | vila
# Processing Record 44 of Set 7 | upernavik
# Processing Record 45 of Set 7 | chingirlau
# Processing Record 46 of Set 7 | trinidad
# Processing Record 47 of Set 7 | tigil
# Processing Record 48 of Set 7 | shestakovo
# Processing Record 49 of Set 7 | genhe
# Processing Record 50 of Set 7 | mount gambier
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | oktyabrskoye
# Processing Record 5 of Set 8 | boulder
# Processing Record 6 of Set 8 | solvychegodsk
# Processing Record 7 of Set 8 | hambantota
# Processing Record 8 of Set 8 | nishihara
# Processing Record 9 of Set 8 | guerrero negro
# Processing Record 10 of Set 8 | sisimiut
# Processing Record 11 of Set 8 | manta
# Processing Record 12 of Set 8 | porto novo
# Processing Record 13 of Set 8 | hovd
# Processing Record 14 of Set 8 | athabasca
# Processing Record 15 of Set 8 | rio gallegos
# Processing Record 16 of Set 8 | grand gaube
# Processing Record 17 of Set 8 | dongli
# Processing Record 18 of Set 8 | rawson
# Processing Record 19 of Set 8 | alyangula
# Processing Record 20 of Set 8 | machilipatnam
# Processing Record 21 of Set 8 | marzuq
# Processing Record 22 of Set 8 | mogadishu
# Processing Record 23 of Set 8 | prince albert
# Processing Record 24 of Set 8 | istok
# Processing Record 25 of Set 8 | tasiilaq
# Processing Record 26 of Set 8 | hualmay
# Processing Record 27 of Set 8 | wewak
# Processing Record 28 of Set 8 | lubao
# Processing Record 29 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 8 | luanda
# Processing Record 32 of Set 8 | waipawa
# Processing Record 33 of Set 8 | batagay
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | fethiye
# Processing Record 36 of Set 8 | sim
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | lompoc
# Processing Record 39 of Set 8 | ipora
# Processing Record 40 of Set 8 | salaga
# Processing Record 41 of Set 8 | siguiri
# Processing Record 42 of Set 8 | richards bay
# Processing Record 43 of Set 8 | baghdad
# Processing Record 44 of Set 8 | gimli
# Processing Record 45 of Set 8 | huautla
# Processing Record 46 of Set 8 | nome
# Processing Record 47 of Set 8 | cabo san lucas
# Processing Record 48 of Set 8 | labuhan
# Processing Record 49 of Set 8 | chara
# Processing Record 50 of Set 8 | sur
# Processing Record 1 of Set 9 | kushiro
# Processing Record 2 of Set 9 | oranjemund
# Processing Record 3 of Set 9 | andenes
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | lufilufi
# Processing Record 6 of Set 9 | albert lea
# Processing Record 7 of Set 9 | avanashi
# City not found. Skipping...
# Processing Record 8 of Set 9 | otta
# Processing Record 9 of Set 9 | saint-francois
# Processing Record 10 of Set 9 | warri
# Processing Record 11 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | ketchikan
# Processing Record 14 of Set 9 | kaitangata
# Processing Record 15 of Set 9 | takapau
# Processing Record 16 of Set 9 | sobolevo
# Processing Record 17 of Set 9 | arlit
# Processing Record 18 of Set 9 | daru
# Processing Record 19 of Set 9 | huntsville
# Processing Record 20 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 9 | lasa
# Processing Record 22 of Set 9 | kamloops
# Processing Record 23 of Set 9 | chumikan
# Processing Record 24 of Set 9 | mitu
# Processing Record 25 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 26 of Set 9 | aklavik
# Processing Record 27 of Set 9 | hofn
# Processing Record 28 of Set 9 | nombre de dios
# Processing Record 29 of Set 9 | iralaya
# Processing Record 30 of Set 9 | traralgon
# Processing Record 31 of Set 9 | igrim
# Processing Record 32 of Set 9 | sakakah
# Processing Record 33 of Set 9 | taveta
# Processing Record 34 of Set 9 | ulety
# Processing Record 35 of Set 9 | namatanai
# Processing Record 36 of Set 9 | mayumba
# Processing Record 37 of Set 9 | chapais
# Processing Record 38 of Set 9 | zaporizhzhya
# Processing Record 39 of Set 9 | kemijarvi
# Processing Record 40 of Set 9 | talara
# Processing Record 41 of Set 9 | rockport
# Processing Record 42 of Set 9 | saint anthony
# Processing Record 43 of Set 9 | uk
# City not found. Skipping...
# Processing Record 44 of Set 9 | abha
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | plouzane
# Processing Record 47 of Set 9 | samarai
# Processing Record 48 of Set 9 | cotonou
# Processing Record 49 of Set 9 | chicama
# Processing Record 50 of Set 9 | halifax
# Processing Record 1 of Set 10 | college
# Processing Record 2 of Set 10 | bengkulu
# Processing Record 3 of Set 10 | oussouye
# Processing Record 4 of Set 10 | lanzhou
# Processing Record 5 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 10 | gatesville
# Processing Record 7 of Set 10 | xushan
# Processing Record 8 of Set 10 | puerto del rosario
# Processing Record 9 of Set 10 | aboisso
# Processing Record 10 of Set 10 | oudtshoorn
# Processing Record 11 of Set 10 | karratha
# Processing Record 12 of Set 10 | vilyuysk
# Processing Record 13 of Set 10 | lata
# Processing Record 14 of Set 10 | nyaunglebin
# Processing Record 15 of Set 10 | buraydah
# Processing Record 16 of Set 10 | yining
# Processing Record 17 of Set 10 | tabas
# Processing Record 18 of Set 10 | ibicarai
# Processing Record 19 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 10 | cuzama
# Processing Record 21 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 10 | sorland
# Processing Record 23 of Set 10 | mandalgovi
# Processing Record 24 of Set 10 | marsa matruh
# Processing Record 25 of Set 10 | rexburg
# Processing Record 26 of Set 10 | gizo
# Processing Record 27 of Set 10 | kargasok
# Processing Record 28 of Set 10 | poco das trincheiras
# Processing Record 29 of Set 10 | vila franca do campo
# Processing Record 30 of Set 10 | mirnyy
# Processing Record 31 of Set 10 | yeppoon
# Processing Record 32 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 34 of Set 10 | acajutla
# Processing Record 35 of Set 10 | cururupu
# Processing Record 36 of Set 10 | kencong
# Processing Record 37 of Set 10 | kashirskoye
# Processing Record 38 of Set 10 | tabou
# Processing Record 39 of Set 10 | whitehorse
# Processing Record 40 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 41 of Set 10 | hay river
# Processing Record 42 of Set 10 | darnah
# Processing Record 43 of Set 10 | neuquen
# Processing Record 44 of Set 10 | katha
# City not found. Skipping...
# Processing Record 45 of Set 10 | ust-koksa
# Processing Record 46 of Set 10 | karur
# Processing Record 47 of Set 10 | aloleng
# Processing Record 48 of Set 10 | araouane
# Processing Record 49 of Set 10 | tselinnoye
# Processing Record 50 of Set 10 | burica
# City not found. Skipping...
# Processing Record 1 of Set 11 | lavrentiya
# Processing Record 2 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 3 of Set 11 | polyarnyy
# Processing Record 4 of Set 11 | segezha
# Processing Record 5 of Set 11 | shunyi
# Processing Record 6 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 7 of Set 11 | markova
# Processing Record 8 of Set 11 | noshiro
# Processing Record 9 of Set 11 | inongo
# Processing Record 10 of Set 11 | kuala terengganu
# Processing Record 11 of Set 11 | bang khla
# Processing Record 12 of Set 11 | yanam
# Processing Record 13 of Set 11 | moerai
# Processing Record 14 of Set 11 | aranos
# Processing Record 15 of Set 11 | gairo
# Processing Record 16 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 17 of Set 11 | san jose
# Processing Record 18 of Set 11 | starkville
# Processing Record 19 of Set 11 | biak
# Processing Record 20 of Set 11 | carballo
# Processing Record 21 of Set 11 | tuatapere
# Processing Record 22 of Set 11 | sao filipe
# Processing Record 23 of Set 11 | kloulklubed
# Processing Record 24 of Set 11 | charlestown
# Processing Record 25 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 26 of Set 11 | ajaccio
# Processing Record 27 of Set 11 | christchurch
# Processing Record 28 of Set 11 | vila velha
# Processing Record 29 of Set 11 | camacha
# Processing Record 30 of Set 11 | morondava
# Processing Record 31 of Set 11 | punta alta
# Processing Record 32 of Set 11 | foam lake
# Processing Record 33 of Set 11 | port hueneme
# Processing Record 34 of Set 11 | san fernando
# Processing Record 35 of Set 11 | penzance
# Processing Record 36 of Set 11 | tupik
# Processing Record 37 of Set 11 | tarauaca
# Processing Record 38 of Set 11 | ahipara
# Processing Record 39 of Set 11 | luang prabang
# Processing Record 40 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 11 | svetlogorsk
# Processing Record 42 of Set 11 | ribe
# Processing Record 43 of Set 11 | oparino
# Processing Record 44 of Set 11 | chalus
# Processing Record 45 of Set 11 | ariano irpino
# Processing Record 46 of Set 11 | vanavara
# Processing Record 47 of Set 11 | virginia beach
# Processing Record 48 of Set 11 | lagos
# Processing Record 49 of Set 11 | kant
# Processing Record 50 of Set 11 | berlevag
# Processing Record 1 of Set 12 | voh
# Processing Record 2 of Set 12 | pangnirtung
# Processing Record 3 of Set 12 | moroto
# Processing Record 4 of Set 12 | wladyslawowo
# Processing Record 5 of Set 12 | kurbnesh
# Processing Record 6 of Set 12 | morgan city
# Processing Record 7 of Set 12 | broome
# Processing Record 8 of Set 12 | muravlenko
# Processing Record 9 of Set 12 | provost
# Processing Record 10 of Set 12 | plettenberg bay
# Processing Record 11 of Set 12 | veraval
# Processing Record 12 of Set 12 | nabire
# Processing Record 13 of Set 12 | sambava
# Processing Record 14 of Set 12 | pisco
# Processing Record 15 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 16 of Set 12 | golden
# Processing Record 17 of Set 12 | pathankot
# Processing Record 18 of Set 12 | kondinskoye
# Processing Record 19 of Set 12 | jumla
# Processing Record 20 of Set 12 | mehran
# Processing Record 21 of Set 12 | namibe
# Processing Record 22 of Set 12 | rudbar
# Processing Record 23 of Set 12 | cefalu
# Processing Record 24 of Set 12 | sosnovoborsk
# Processing Record 25 of Set 12 | aginskoye
# Processing Record 26 of Set 12 | korla
# Processing Record 27 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 12 | tiznit
# Processing Record 29 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 30 of Set 12 | okato
# Processing Record 31 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 12 | sovetskiy
# Processing Record 33 of Set 12 | kargat
# Processing Record 34 of Set 12 | huarmey
# Processing Record 35 of Set 12 | hami
# Processing Record 36 of Set 12 | sola
# Processing Record 37 of Set 12 | pak chong
# Processing Record 38 of Set 12 | verkhnyaya maksakovka
# Processing Record 39 of Set 12 | rybnaya sloboda
# Processing Record 40 of Set 12 | kushima
# Processing Record 41 of Set 12 | freeport
# Processing Record 42 of Set 12 | port moresby
# Processing Record 43 of Set 12 | sistranda
# Processing Record 44 of Set 12 | tubuala
# Processing Record 45 of Set 12 | arman
# Processing Record 46 of Set 12 | bougouni
# Processing Record 47 of Set 12 | souillac
# Processing Record 48 of Set 12 | iqaluit
# Processing Record 49 of Set 12 | shimoda
# Processing Record 50 of Set 12 | hongjiang
# Processing Record 1 of Set 13 | margate
# Processing Record 2 of Set 13 | altea
# Processing Record 3 of Set 13 | novikovo
# Processing Record 4 of Set 13 | pailon
# Processing Record 5 of Set 13 | channel-port aux basques
# Processing Record 6 of Set 13 | qandala
# Processing Record 7 of Set 13 | mananara
# Processing Record 8 of Set 13 | fukue
# Processing Record 9 of Set 13 | bossier city
# Processing Record 10 of Set 13 | santa elena
# Processing Record 11 of Set 13 | eydhafushi
# Processing Record 12 of Set 13 | zabaykalsk
# Processing Record 13 of Set 13 | malayal
# Processing Record 14 of Set 13 | mitsamiouli
# Processing Record 15 of Set 13 | gamboula
# Processing Record 16 of Set 13 | chipinge
# Processing Record 17 of Set 13 | leshukonskoye
# Processing Record 18 of Set 13 | newry
# Processing Record 19 of Set 13 | shingu
# Processing Record 20 of Set 13 | miraflores
# Processing Record 21 of Set 13 | honiara
# Processing Record 22 of Set 13 | bilma
# Processing Record 23 of Set 13 | coihaique
# Processing Record 24 of Set 13 | salta
# Processing Record 25 of Set 13 | ruwi
# Processing Record 26 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 27 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 13 | vardo
# Processing Record 29 of Set 13 | husavik
# Processing Record 30 of Set 13 | taltal
# Processing Record 31 of Set 13 | upata
# Processing Record 32 of Set 13 | victoria point
# Processing Record 33 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 13 | troitskoye
# Processing Record 35 of Set 13 | kalininsk
# Processing Record 36 of Set 13 | borama
# City not found. Skipping...
# Processing Record 37 of Set 13 | saint-ambroise
# Processing Record 38 of Set 13 | kuala lipis
# Processing Record 39 of Set 13 | bintulu
# Processing Record 40 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 41 of Set 13 | mwingi
# Processing Record 42 of Set 13 | masuda
# Processing Record 43 of Set 13 | rayadrug
# Processing Record 44 of Set 13 | warwick
# Processing Record 45 of Set 13 | homer
# Processing Record 46 of Set 13 | forbes
# Processing Record 47 of Set 13 | yelanskiy
# Processing Record 48 of Set 13 | port maria
# Processing Record 49 of Set 13 | rocha
# Processing Record 50 of Set 13 | dukat
# Processing Record 1 of Set 14 | bernardino de campos
# Processing Record 2 of Set 14 | beringovskiy
# Processing Record 3 of Set 14 | otkaznoye
# Processing Record 4 of Set 14 | gonaives
# Processing Record 5 of Set 14 | vire
# Processing Record 6 of Set 14 | asfi
# Processing Record 7 of Set 14 | solnechnyy
# Processing Record 8 of Set 14 | colomi
# Processing Record 9 of Set 14 | kiama
# Processing Record 10 of Set 14 | ufimskiy
# Processing Record 11 of Set 14 | hervey bay
# Processing Record 12 of Set 14 | palembang
# Processing Record 13 of Set 14 | opuwo
# Processing Record 14 of Set 14 | hadejia
# Processing Record 15 of Set 14 | srednekolymsk
# Processing Record 16 of Set 14 | ngorongoro
# Processing Record 17 of Set 14 | razgrad
# Processing Record 18 of Set 14 | delijan
# Processing Record 19 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 14 | aksu
# Processing Record 21 of Set 14 | half moon bay
# Processing Record 22 of Set 14 | bazaliya
# Processing Record 23 of Set 14 | griffith
# Processing Record 24 of Set 14 | tzaneen
# Processing Record 25 of Set 14 | yerbogachen
# Processing Record 26 of Set 14 | tefe
# Processing Record 27 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 28 of Set 14 | awjilah
# Processing Record 29 of Set 14 | linxia
# Processing Record 30 of Set 14 | san sebastian
# Processing Record 31 of Set 14 | sapa
# Processing Record 32 of Set 14 | canavieiras
# Processing Record 33 of Set 14 | doha
# Processing Record 34 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 14 | port hawkesbury
# Processing Record 36 of Set 14 | lishui
# Processing Record 37 of Set 14 | znamenskoye
# Processing Record 38 of Set 14 | pimentel
# Processing Record 39 of Set 14 | garowe
# Processing Record 40 of Set 14 | keetmanshoop
# Processing Record 41 of Set 14 | aanekoski
# Processing Record 42 of Set 14 | bulgan
# Processing Record 43 of Set 14 | barranca
# Processing Record 44 of Set 14 | brasileia
# Processing Record 45 of Set 14 | balve
# Processing Record 46 of Set 14 | karaton
# Processing Record 47 of Set 14 | roma
# Processing Record 48 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 49 of Set 14 | coatlan
# City not found. Skipping...
# Processing Record 50 of Set 14 | kalloni
# Processing Record 1 of Set 15 | helmsdale
# Processing Record 2 of Set 15 | walvis bay
# Processing Record 3 of Set 15 | ponta delgada
# Processing Record 4 of Set 15 | waddan
# Processing Record 5 of Set 15 | tazmalt
# Processing Record 6 of Set 15 | chute-aux-outardes
# Processing Record 7 of Set 15 | langenau
# Processing Record 8 of Set 15 | khandagayty
# Processing Record 9 of Set 15 | lamu
# Processing Record 10 of Set 15 | tome
# Processing Record 11 of Set 15 | nerchinsk
# Processing Record 12 of Set 15 | comodoro rivadavia
# Processing Record 13 of Set 15 | stekolnyy
# City not found. Skipping...
# Processing Record 14 of Set 15 | nizhneudinsk
# Processing Record 15 of Set 15 | road town
# Processing Record 16 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 15 | kansanshi
# Processing Record 18 of Set 15 | mayo
# Processing Record 19 of Set 15 | kidal
# Processing Record 20 of Set 15 | jardim
# Processing Record 21 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 15 | koboko
# Processing Record 23 of Set 15 | mandera
# Processing Record 24 of Set 15 | olinda
# Processing Record 25 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 15 | gigmoto
# Processing Record 27 of Set 15 | villach
# Processing Record 28 of Set 15 | montepuez
# Processing Record 29 of Set 15 | amapa
# Processing Record 30 of Set 15 | ronne
# Processing Record 31 of Set 15 | aykhal
# Processing Record 32 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 15 | sao jose da coroa grande
# Processing Record 34 of Set 15 | inzer
# Processing Record 35 of Set 15 | simao
# Processing Record 36 of Set 15 | kiunga
# Processing Record 37 of Set 15 | matagami
# Processing Record 38 of Set 15 | pochutla
# Processing Record 39 of Set 15 | lewistown
# Processing Record 40 of Set 15 | ajdabiya
# Processing Record 41 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 15 | bubaque
# Processing Record 43 of Set 15 | emirdag
# Processing Record 44 of Set 15 | tarsus
# Processing Record 45 of Set 15 | zhucheng
# Processing Record 46 of Set 15 | miandrivazo
# Processing Record 47 of Set 15 | vaitape
# Processing Record 48 of Set 15 | pittsburg
# Processing Record 49 of Set 15 | kabinda
# Processing Record 50 of Set 15 | nueva concepcion
# Processing Record 1 of Set 16 | mpika
# Processing Record 2 of Set 16 | semey
# Processing Record 3 of Set 16 | evensk
# Processing Record 4 of Set 16 | andros town
# Processing Record 5 of Set 16 | stornoway
# Processing Record 6 of Set 16 | grand island
# Processing Record 7 of Set 16 | marolambo
# Processing Record 8 of Set 16 | bonfim
# Processing Record 9 of Set 16 | khuzdar
# Processing Record 10 of Set 16 | brewster
# Processing Record 11 of Set 16 | suba
# Processing Record 12 of Set 16 | flinders
# Processing Record 13 of Set 16 | loandjili
# Processing Record 14 of Set 16 | sungai besar
# Processing Record 15 of Set 16 | pangai
# Processing Record 16 of Set 16 | povenets
# Processing Record 17 of Set 16 | padang
# Processing Record 18 of Set 16 | pavilosta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Two Rivers  44.15  -87.57     80.01        61          20        8.05
# 1        Hobart -42.88  147.33     45.00        73          75       10.29
# 2  Constitucion -35.33  -72.42     51.40        71           0        4.94
# 3      Meulaboh   4.14   96.13     78.33        85         100        3.80
# 4  Puerto Ayora  -0.74  -90.35     66.99        87          68       10.00
# 5     Esperance -33.87  121.90     46.40       100          75        3.36
# 6       Kavieng  -2.57  150.80     84.06        73          20        9.19
# 7     Pingliang  35.54  106.69     62.89        87          92       13.27
# 8  Punta Arenas -53.15  -70.92     44.60        75          75       16.11
# 9        Albany  42.60  -73.97     75.99        49           9        1.99
#
#   Country Current Description
# 0      US          few clouds
# 1      AU       broken clouds
# 2      CL           clear sky
# 3      ID       moderate rain
# 4      EC       broken clouds
# 5      AU       broken clouds
# 6      PG          few clouds
# 7      CN     overcast clouds
# 8      CL       broken clouds
# 9      US           clear sky

# %%
new_col_ord = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_col_ord]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Two Rivers      US  44.15  -87.57     80.01        61          20
# 1        Hobart      AU -42.88  147.33     45.00        73          75
# 2  Constitucion      CL -35.33  -72.42     51.40        71           0
# 3      Meulaboh      ID   4.14   96.13     78.33        85         100
# 4  Puerto Ayora      EC  -0.74  -90.35     66.99        87          68
# 5     Esperance      AU -33.87  121.90     46.40       100          75
# 6       Kavieng      PG  -2.57  150.80     84.06        73          20
# 7     Pingliang      CN  35.54  106.69     62.89        87          92
# 8  Punta Arenas      CL -53.15  -70.92     44.60        75          75
# 9        Albany      US  42.60  -73.97     75.99        49           9
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1       10.29       broken clouds
# 2        4.94           clear sky
# 3        3.80       moderate rain
# 4       10.00       broken clouds
# 5        3.36       broken clouds
# 6        9.19          few clouds
# 7       13.27     overcast clouds
# 8       16.11       broken clouds
# 9        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
